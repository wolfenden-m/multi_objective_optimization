# %% [markdown]
# # Part 4: Iteractive ChatBot
# If you have any questions about what we reviewed, from inquires about the script itself to applications to your own use cases, here is the place!
# Some examples:

# %%
from chatbot import ask_model
query1 = "Why did MOPSO-CD underperform in our suitcase example problem? In what circumstance would MOPSO-CD outperform other algorithms?"
ask_model(query1)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ================================ Human Message =================================
#
# Why did MOPSO-CD underperform in our suitcase example problem? In what circumstance would MOPSO-CD outperform other algorithms?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (79e4c4dha)
#  Call ID: 79e4c4dha
#   Args:
#     query: MOPSO-CD suitcase problem performance comparison
# ================================= Tool Message =================================
# Name: retrieve_context
#
#
# ================================== Ai Message ==================================
#
# ...

# %%
query2 = "I want to minimize payroll while maximizing the experience level of my team. I care about experience more, but hiring only the most qualified is definately too expensive. What should I do?"
ask_model(query2)
# Out:
# ================================ Human Message =================================
#
# I want to minimize payroll while maximizing the experience level of my team. I care about experience more, but hiring only the most qualified is definately too expensive. What should I do?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (vv2b4rehm)
#  Call ID: vv2b4rehm
#   Args:
#     query: Balance team experience and payroll cost strategies
# ================================= Tool Message =================================
# Name: retrieve_context
#
#
# ================================== Ai Message ==================================
#
# To address your goal of balancing team experience with payroll costs, here's a structured approach:
#
# 1. **Classify**: This is a **Multi-Objective Optimization (MOO)** problem, as you’re simultaneously minimizing cost and maximizing experience.
#
# ...
